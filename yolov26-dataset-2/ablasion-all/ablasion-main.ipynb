# %%
import torch
from ultralytics import YOLO
import ultralytics.nn.tasks as tasks
import ultralytics.nn.modules as modules
#from affpn import patch_concat_to_affpn
from bifpn import patch_concat_to_bifpn
from hybrid_fusion import patch_concat_to_hybrid
from spdconv import SPDConv   # ya da senin dosya adın neyse
tasks.SPDConv = SPDConv
from wiseiou import patch_bbox_iou_with_wiou
patch_bbox_iou_with_wiou(monotonous=False)
# Out:
# [wise_iou] patched ultralytics.utils.loss.bbox_iou -> Wise-IoU v3 (non-monotonic focusing)

# %%
device = 0 if torch.cuda.is_available() else "cpu"
print(f"Kullanilan cihaz: {'GPU (cuda:0)' if device == 0 else 'CPU'}")
if device == "cpu":
    print("UYARI: GPU bulunamadi, egitim CPU'da yapilacak ve cok yavas olabilir.")
# Out:
# Kullanilan cihaz: GPU (cuda:0)

# %%
# Concat -> WeightedConcat
# # Bu satır YOLO(...) satırından önce çalışmalı.
#patch_concat_to_affpn()
# patch_concat_to_bifpn()
# patch_concat_to_hybrid()
# Out:
# [hybrid_fusion] patched Concat -> HybridBiAFFPNConcat (BiFPN weighted-fusion + AFFPN attention)

# %%
# 1) P2 head'li YOLO26 mimarisini (henüz eğitilmemiş yapı) oluştur
#    "s" ölçeğini baseline ile aynı tut ki ağırlık transferi daha sağlıklı olsun
model = YOLO("spdconv_bifpn_p2.yaml").load("../baseline/runs/detect/train/weights/best.pt").load("../BIFPN/runs/detect/ablation_bifpn_v1/weights/best.pt").load("../SPD-Conv/runs/detect/ablation_spd_conv_v/weights/best.pt")   # kendi baseline yolunu yaz

# 2) Baseline eğitiminden çıkan ağırlıkları yükle
#    .load() ismi/shape'i eşleşen katmanları (backbone, P3-P4-P5) otomatik aktarır,
#    yeni eklenen P2 katmanları rastgele başlatılmış olarak kalır
#model.load("runs/detect/train/weights/best.pt")  # kendi baseline yolunu yaz
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# Transferred 356/1022 items from pretrained weights
# Transferred 360/1022 items from pretrained weights
# Transferred 360/1022 items from pretrained weights

# %%
# --- Aşama A: Backbone dondurulmuş, yeni katmanlar + head ısınıyor ---
model.train(
    data="../../../dataset2/yolo26/YOLO.v1i.yolo26/data.yaml",
    epochs=500,
    imgsz=640,
    batch=16,
    optimizer="SGD",
    device=device,
    name="bifpn+spd-covn+p2+wise-iou",
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.129 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.118  Python-3.12.9 torch-2.13.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../../../dataset2/yolo26/YOLO.v1i.yolo26/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=500, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=spdconv_bifpn_p2.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=bifpn+spd-covn+p2+wise-iou-5, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=../SPD-Conv/runs/detect/ablation_spd_conv_v/weights/best.pt, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\ertug\Desktop\yolo\codes\yolov26-dataset-2\ablasion-all\runs\detect\bifpn+spd-covn+p2+wise-iou-5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
# WARNING no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1760  spdconv.SPDConv                              [3, 16, 3, 2]
#   1                  -1  1     18496  spdconv.SPDConv                              [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1    147584  spdconv.SPDConv                              [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    590080  spdconv.SPDConv                              [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1   1180160  spdconv.SPDConv                              [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  hybrid_fusion.HybridBiAFFPNConcat            [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  hybrid_fusion.HybridBiAFFPNConcat            [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  18             [-1,
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\ultralytics\engine\trainer.py:243, in BaseTrainer.train(self)
#     240             ddp_cleanup(self, str(file))
#     242 else:
# --> 243     self._do_train()
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\ultralytics\engine\trainer.py:494, in BaseTrainer._do_train(self)
#     492     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     493 else:
# --> 494     loss, self.loss_items = self.model(batch)
#     495 self.loss = loss.sum()
#     496 if RANK != -1:
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\ultralytics\nn\tasks.py:157, in BaseModel.forward(self, x, *args, **kwargs)
#     144 """Perform forward pass of the model for either training or inference.
#     145
#     146 If x is a dict, calculates and returns the loss for training. Otherwise, returns predictions for inference.
#    (...)    154     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     155 """
#     156 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 157     return self.loss(x, *args, **kwargs)
#     158 return self.predict(x, *args, **kwargs)
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\ultralytics\nn\tasks.py:414, in BaseModel.loss(self, batch, preds)
#     411     self.criterion = self.init_criterion()
#     413 if preds is None:
# --> 414     preds = self.forward(batch["img"])
#     415 return self.criterion(preds, batch)
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\ultralytics\nn\tasks.py:158, in BaseModel.forward(self, x, *args, **kwargs)
#     156 if isinstance(x, dict):  # for cases of training and validating while training.
#     157     return self.loss(x, *args, **kwargs)
# --> 158 return self.predict(x, *args, **kwargs)
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\ultralytics\nn\tasks.py:174, in BaseModel.predict(self, x, profile, augment, embed)
#     172 if augment:
#     173     return self._predict_augment(x)
# --> 174 return self._predict_once(x, profile, embed)
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\ultralytics\nn\tasks.py:195, in BaseModel._predict_once(self, x, profile, embed)
#     193 if profile:
#     194     self._profile_one_layer(m, x, dt)
# --> 195 x = m(x)  # run
#     196 y.append(x if m.i in self.save else None)  # save output
#     197 if m.i in embed:
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\ultralytics\nn\modules\head.py:177, in Detect.forward(self, x)
#     175 if self.end2end:
#     176     x_detach = [xi.detach() for xi in x] if self.training else x  # detach keeps one2one out of the backbone
# --> 177     one2one = self.forward_head(x_detach, **self.one2one)
#     178     preds = {"one2many": preds, "one2one": one2one}
#     179 if self.training:
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\ultralytics\nn\modules\head.py:167, in Detect.forward_head(self, x, box_head, cls_head)
#     165 bs = x[0].shape[0]  # batch size
#     166 boxes = torch.cat([box_head[i](x[i]).view(bs, 4 * self.reg_max, -1) for i in range(self.nl)], dim=-1)
# --> 167 scores = torch.cat([cls_head[i](x[i]).view(bs, self.nc, -1) for i in range(self.nl)], dim=-1)
#     168 return {"boxes": boxes, "scores": scores, "feats": x}
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\ultralytics\nn\modules\conv.py:78, in Conv.forward(self, x)
#      69 def forward(self, x):
#      70     """Apply convolution, batch normalization and activation to input tensor.
#      71
#      72     Args:
#    (...)     76         (torch.Tensor): Output tensor.
#      77     """
# ---> 78     return self.act(self.bn(self.conv(x)))
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\conv.py:565, in Conv2d.forward(self, input)
#     564 def forward(self, input: Tensor) -> Tensor:
# --> 565     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\ertug\Desktop\yolo\.venv\Lib\site-packages\torch\nn\modules\conv.py:560, in Conv2d._conv_forward(self, input, weight, bias)
#     547 if self.padding_mode != "zeros":
#     548     return F.conv2d(
#     549         F.pad(
#     550             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    557         self.groups,
#     558     )
# --> 560 return F.conv2d(
#     561     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     562 )
#
# KeyboardInterrupt:

# %%
from ultralytics import YOLO
from pathlib import Path
import torch

model_path = Path("runs/detect/bifpn+spd-covn+p2+wise-iou-4/weights/best.pt")  #TODO : kendi model yolunu yaz
if model_path.exists():
    model = YOLO(str(model_path))
    print(f"Test ediliyor: {model_path}")
    results = model.val(
        data="../../../dataset2/yolo26/YOLO.v1i.yolo26/data.yaml",
        split="test",
        imgsz=640,
        device=0 if torch.cuda.is_available() else "cpu",
    )

    metrics = results.results_dict
    precision = metrics.get("metrics/precision(B)", None)
    recall = metrics.get("metrics/recall(B)", None)
    map50 = metrics.get("metrics/mAP50(B)", None)
    map5095 = metrics.get("metrics/mAP50-95(B)", None)

    print("\nTest metrikleri:")
    print(f"Precision: {precision * 100:.2f}%" if precision is not None else "Precision: bulunamadı")
    print(f"Recall: {recall * 100:.2f}%" if recall is not None else "Recall: bulunamadı")
    print(f"mAP@0.5: {map50 * 100:.2f}%" if map50 is not None else "mAP@0.5: bulunamadı")
    print(f"mAP@0.5-0.95: {map5095 * 100:.2f}%" if map5095 is not None else "mAP@0.5-0.95: bulunamadı")
else:
    print(f"Model bulunamadı: {model_path}")
# Out:
# Test ediliyor: runs\detect\bifpn+spd-covn+p2+wise-iou-4\weights\best.pt
# Ultralytics 8.4.118  Python-3.12.9 torch-2.13.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# spdconv_bifpn_p2 summary: 240 layers, 4,868,106 parameters, 0 gradients
# val: Fast image access  (ping: 0.00.0 ms, read: 88.131.8 MB/s, size: 26.7 KB)
# val: Scanning C:\Users\ertug\Desktop\yolo\dataset2\yolo26\YOLO.v1i.yolo26\test\labels.cache... 279 images, 0 backgrounds, 10 corrupt: 100% ━━━━━━━━━━━━ 279/279  0.0s
# val: C:\Users\ertug\Desktop\yolo\dataset2\yolo26\YOLO.v1i.yolo26\test\images\im171_jpg.rf.e4ef6151dffe621e681fe4ca6f8e2f1b.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: C:\Users\ertug\Desktop\yolo\dataset2\yolo26\YOLO.v1i.yolo26\test\images\im227_jpg.rf.5070aa166043d7744a73e2b8ff14b0b4.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: C:\Users\ertug\Desktop\yolo\dataset2\yolo26\YOLO.v1i.yolo26\test\images\im227_jpg.rf.88d4ecb5fc66b992377cec7e5d187b24.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: C:\Users\ertug\Desktop\yolo\dataset2\yolo26\YOLO.v1i.yolo26\test\images\im227_jpg.rf.9eee427fad5e8f777b2d7886402a16ba.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: C:\Users\ertug\Desktop\yolo\dataset2\yolo26\YOLO.v1i.yolo26\test\images\im227_jpg.rf.b28b88e11d852e328873fb8760e724ba.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: C:\Users\ertug\Desktop\yolo\dataset2\yolo26\YOLO.v1i.yolo26\test\images\im256_jpg.rf.1d604f32ffc1dff1c09028fb82304087.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: C:\Users\ertug\Desktop\yolo\dataset2\yolo26\YOLO.v1i.yolo26\test\images\im256_jpg.rf.c8343c143ca8d9f2a92db9f257fa6eeb.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: C:\Users\ertug\Desktop\yolo\dataset2\yolo26\YOLO.v1i.yolo26\test\images\im47_jpg.rf.e131e058faf7a82bc1a8a74c51497b78.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: C:\Users\ertug\Desktop\yolo\dataset2\yolo26\YOLO.v1i.yolo26\test\images\im50_jpg.rf.31e9d09aaefc19ee355f7988aea9b246.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: C:\Users\ertug\Desktop\yolo\dataset2\yolo26\YOLO.v1i.yolo26\test\images\im58_jpg.rf.2344363972ee4217f8e23810e16be4cd.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# WARNING Box and segment counts should be equal, but got len(segments) = 226, len(boxes) = 924. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 5.4it/s 3.2s0.2s
#                    all        269        924      0.465      0.546      0.482      0.347
#                  crack        182        637      0.479       0.58      0.494      0.342
#                   dent        102        287      0.452      0.512       0.47      0.351
# Speed: 1.4ms preprocess, 8.2ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to C:\Users\ertug\Desktop\yolo\codes\yolov26-dataset-2\ablasion-all\runs\detect\val-20
#
# Test metrikleri:
# Precision: 46.54%
# Recall: 54.59%
# mAP@0.5: 48.19%
# mAP@0.5-0.95: 34.65%
